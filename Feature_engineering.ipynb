# %% [markdown]
# <a href="https://colab.research.google.com/github/vishesh711/Machine-Learning-Practice/blob/main/Feature_engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Feature Engineering
# Feature engineering is the process of transforming raw data into meaningful features that better represent the underlying problem to the machine learning model. It involves creating new features or modifying existing ones to improve the model’s performance.
#
# Feature engineering can often lead to significant improvements in a model's performance, and it's an essential step in the machine learning pipeline.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.preprocessing import PolynomialFeatures

# Example feature
X = [[2], [3], [4]]

# Creating a polynomial feature (degree 2)
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

print(X_poly)
# Out:
# [[ 1.  2.  4.]
#  [ 1.  3.  9.]
#  [ 1.  4. 16.]]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# Example feature
X = np.array([1, 10, 100, 1000])

# Applying log transformation
X_log = np.log(X)

print(X_log)
# Out:
# [0.         2.30258509 4.60517019 6.90775528]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# Example feature
X = pd.Series([22, 25, 47, 51, 19, 31, 45])

# Binning the ages into categories
bins = [0, 18, 35, 50, 100]
labels = ['Teen', 'Young Adult', 'Middle-aged', 'Senior']
X_binned = pd.cut(X, bins=bins, labels=labels)

print(X_binned)
# Out:
# 0    Young Adult
# 1    Young Adult
# 2    Middle-aged
# 3         Senior
# 4    Young Adult
# 5    Young Adult
# 6    Middle-aged
# dtype: category
# Categories (4, object): ['Teen' < 'Young Adult' < 'Middle-aged' < 'Senior']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.preprocessing import MinMaxScaler

# Example feature
X = [[-1, 2], [-0.5, 6], [0, 10], [1, 18]]

# Applying Min-Max scaling
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

print(X_scaled)
# Out:
# [[0.   0.  ]
#  [0.25 0.25]
#  [0.5  0.5 ]
#  [1.   1.  ]]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.preprocessing import StandardScaler

# Example feature
X = [[-1, 2], [-0.5, 6], [0, 10], [1, 18]]

# Applying standardization
scaler = StandardScaler()
X_standardized = scaler.fit_transform(X)

print(X_standardized)
# Out:
# [[-1.18321596 -1.18321596]
#  [-0.50709255 -0.50709255]
#  [ 0.16903085  0.16903085]
#  [ 1.52127766  1.52127766]]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
from sklearn.impute import SimpleImputer

# Example feature with missing values
X = [[1, 2], [np.nan, 3], [7, 6], [9, np.nan]]

# Applying mean imputation
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

print(X_imputed)
# Out:
# [[1.         2.        ]
#  [5.66666667 3.        ]
#  [7.         6.        ]
#  [9.         3.66666667]]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# Example categorical feature
X = pd.DataFrame({'Color': ['Red', 'Blue', 'Green', 'Blue']})

# Applying one-hot encoding
X_encoded = pd.get_dummies(X, prefix='Color')

print(X_encoded)
# Out:
#    Color_Blue  Color_Green  Color_Red
# 0       False        False       True
# 1        True        False      False
# 2       False         True      False
# 3        True        False      False

# %% [markdown]
# ###Conclusion on Feature Engineering
# Feature engineering is critical in enhancing the performance of machine learning models. By transforming raw data into meaningful features, you can significantly improve your model’s accuracy and generalizability. Understanding and applying feature engineering techniques will help build more effective models.
